# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Define file path
path = r'D:\Data Immersion - Careerfoundry\Python Fundamentals for Data Analysts\Instacart Basket Analysis'

# %%
# Import dataframe
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined_complete.pkl'))

# %% [markdown]
# # If-Statements and User Defined Functions

# %%
# Define functioin
def add_num(x,y):
    sum = x + y
    return sum

# %%
# Run function
add_num(9, 11)
# Out:
# 20

# %%
df = ords_prods_merged[:1000000]

# %%
#Define price label function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low Range product'
    elif (row['prices'] > 5) and (row['prices'] <=15):
        return 'Mid Range product'
    elif row['prices'] > 15:
        return 'High Range'
    else: return 'Not enough data'

# %%
# Apply price label function to dataframe
df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# <ipython-input-8-d4f34cdefe5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
# Count the values in price_range column
df['price_range'].value_counts(dropna = False)
# Out:
# Mid Range product    652638
# Low Range product    338018
# High Range             9344
# Name: price_range, dtype: int64

# %%
# Find the max value in prices column
df['prices'].max()
# Out:
# 24.5

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid Range product'
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid Range product     652638
# Low-range product     338018
# High range product      9344
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid Range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts()
# Out:
# Low-range product     10126321
# Mid Range product       652638
# High range product      417678
# Name: price_range_loc, dtype: int64

# %%
for x in range (30, 45):
    print('My age is %d' % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
ords_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 18 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   Unnamed: 0_y            int64
#  7   order_id                int64
#  8   user_id                 int64
#  9   eval_set                object
#  10  order_number            int64
#  11  order_dow               int64
#  12  order_hour_of_day       int64
#  13  days_since_prior_order  float64
#  14  add_to_cart_order       int64
#  15  reordered               int64
#  16  _merge                  category
#  17  price_range_loc         object
# dtypes: category(1), float64(2), int64(12), object(3)
# memory usage: 5.4+ GB

# %%
# Drop eval_set column
df_ords_prods_merged = ords_prods_merged.drop(columns = ['eval_set'])

# %%
# Rename order dow to a more understandable name
df_ords_prods_merged.rename(columns = {'order_dow' : 'orders_day_of_the_week'}, inplace = True)

# %%
# Count values in orders_day_of_the_week column
df_ords_prods_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_the_week, dtype: int64

# %%
# For-loop to label the busiest days of the week for orders
result = []

for value in df_ords_prods_merged['orders_day_of_the_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regular_busy')

# %%
result
# Out:
# ['Regular_busy',
#  'Regular_busy',
#  'Busiest day',
#  'Regular_busy',
#  'Least busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Least busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Busiest day',
#  'Regular_busy',
#  'Regular_busy',
#  'Least busy',
#  'Regular_busy',
#  'Busiest day',
#  'Regular_busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
#  'Regular_busy',
# ...

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regular_busy    22416875
# Busiest day      6204182
# Least busy       3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Task

# %% [markdown]
# ### 2)

# %%
# Get a count of orders_day_of_the_week column
df_ords_prods_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_the_week, dtype: int64

# %% [markdown]
# The two busiest day are Sunday and Monday (0 & 1) and the two slowest days are Friday and Thursday (3 & 4)

# %%
# Label the two busiest days as 'Busiest days', 2 slowest days 'slowest days' and any other day 'Regular busy'
result_1 = []

for value in df_ords_prods_merged['orders_day_of_the_week']:
    if value >= 0 and value <= 1:
        result_1.append('Busiest days')
    elif value >= 3 and value <= 4:
        result_1.append('Slowest days')
    else:
        result_1.append('Regular Busy')

# %%
# Create new column with the new frop loop
df_ords_prods_merged['busiest_days'] = result_1

# %%
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regular Busy    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# ## 3)

# %%
# Add the value counts from the .value_counts to match check our for loop result
x = 6204182
y = 5660230
a = 3783802
b = 3840534

slow_sum = (a + b)
print (slow_sum)

busy_sum = (x + y)
print (busy_sum)
# Out:
# 7624336
# 11864412

# %% [markdown]
# ## 4)

# %%
# Get count of orders of each time of day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# If I was in this scenario, I would ask the technical officer what "too many orders" means to him. But for this case I am going to presume that is means anything over 1 million orders. Then 100,000 < 'average orders' < 1,000,000 and least orders < 100,000

# %%
# Determine the business of the for each time of day
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 8) & (df_ords_prods_merged['order_hour_of_day'] <= 19), 'busiest_period_of_day'] = 'Most orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] == 0) & (df_ords_prods_merged['order_hour_of_day'] ==1) , 'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 6) & (df_ords_prods_merged['order_hour_of_day'] <= 8), 'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 18) & (df_ords_prods_merged['order_hour_of_day'] <=23), 'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day'] >= 2) & (df_ords_prods_merged['order_hour_of_day'] <=5), 'busiest_period_of_day'] = 'Fewest orders'

# %%
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# 2             19     5.8         11433    389851      709             2
# 3             19     5.8         12198    652770      764             1
# 4             19     5.8         12200   1813452      764             3
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# ...

# %% [markdown]
# ## 5)

# %%
# See how many of each value are in the 'busiest_period_of_day' column
df_ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# Most orders       23205725
# Average orders     8602806
# Fewest orders       261859
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ## 7

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  \
# 0             19     5.8          1987   3139998      138            28
# 1             19     5.8          1989   1977647      138            30
# 2             19     5.8         11433    389851      709             2
# 3             19     5.8         12198    652770      764             1
# 4             19     5.8         12200   1813452      764             3
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# ...
